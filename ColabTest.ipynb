# %% [markdown]
# <a href="https://colab.research.google.com/github/CrazyMadcow/MPPI_JAX/blob/main/ColabTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 간단한 python 코드 테스트

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# 간단한 jax 테스트

# %%
import numpy as np

import jax.numpy as jnp
from jax import grad, jit, vmap
from jax import random
# from jax import device_put

# # Prevent GPU/TPU warning.
# import jax; jax.config.update('jax_platform_name', 'cpu')

# %%
key = random.PRNGKey(0)       # seed
x = random.normal(key, (10,)) # random
print(x)        


size = 3000
x = random.normal(key, (size, size), dtype=jnp.float32)
# %timeit jnp.dot(x, x.T).block_until_ready()  # runs on the GPU
# Out:
# [-0.372111    0.26423106 -0.18252774 -0.7368198  -0.44030386 -0.15214427
#  -0.6713536  -0.5908642   0.73168874  0.5673025 ]
# 1 loop, best of 5: 988 ms per loop
